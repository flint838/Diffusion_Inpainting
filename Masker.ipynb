# %%
#DIS TEH ONE
import cv2
import numpy as np

# Load the damaged painting image
painting = cv2.imread('/home/salahuddin/Desktop/Photo-Restoration-using-inpainting/abraham.jpg')

# Convert to grayscale (if necessary)
gray_painting = cv2.cvtColor(painting, cv2.COLOR_BGR2GRAY)

# Thresholding to identify damaged areas (you may need to adjust threshold value)
_, damaged_mask = cv2.threshold(gray_painting, 235, 255, cv2.THRESH_BINARY)

# Invert the mask so that damaged areas are white and background is black
damaged_mask = cv2.bitwise_not(damaged_mask)

# Save the mask image
cv2.imwrite('imask.jpg', damaged_mask)

# Display the mask (optional)
cv2.imshow('Damaged Mask', damaged_mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)
#
# QObject::moveToThread: Current thread (0x55b86e633030) is not the object's thread (0x55b86e879d40).
# Cannot move to target thread (0x55b86e633030)

# %%
from PIL import Image

def invert_colors(image_path, save_path):
    # Open the image
    image = Image.open(image_path)
    
    # Convert image to grayscale if it's not already
    if image.mode != 'L':
        image = image.convert('L')
    
    # Invert colors
    inverted_image = Image.eval(image, lambda x: 255 - x)
    
    # Save the inverted image as jpg
    inverted_image.save(save_path, 'JPEG')

# Specify the path to your image
image_path = '/home/salahuddin/Desktop/imask.jpg'

# Specify the path to save the inverted image
save_path = '/home/salahuddin/Desktop/new_mask.jpg'

# Call the function to invert colors and save the image
invert_colors(image_path, save_path)

# %%
from PIL import Image

def invert_colors(image_path, save_path):
    # Open the image
    image = Image.open(image_path)
    
    # Convert image to grayscale if it's not already
    if image.mode != 'L':
        image = image.convert('L')
    
    # Invert colors
    inverted_image = Image.eval(image, lambda x: 255 - x)
    
    # Save the inverted image as jpg
    inverted_image.save(save_path, 'JPEG')

# Specify the path to your image
image_path = '/home/salahuddin/Desktop/imask.jpg'

# Specify the path to save the inverted image
save_path = '/home/salahuddin/Desktop/new_mask.jpg'

# Call the function to invert colors and save the image
invert_colors(image_path, save_path)

# %%
from PIL import Image

def invert_colors(image_path, save_path):
    # Open the image
    image = Image.open(image_path)
    
    # Convert image to grayscale if it's not already
    if image.mode != 'L':
        image = image.convert('L')
    
    # Invert colors
    inverted_image = Image.eval(image, lambda x: 255 - x)
    
    # Save the inverted image as jpg
    inverted_image.save(save_path, 'JPEG')

# Specify the path to your image
image_path = '/home/salahuddin/Desktop/imask.jpg'

# Specify the path to save the inverted image
save_path = '/home/salahuddin/Desktop/new_mask.jpg'

# Call the function to invert colors and save the image
invert_colors(image_path, save_path)
